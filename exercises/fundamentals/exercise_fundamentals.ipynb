# %% [markdown]
# # 🐍 Python Fundamentals — Exercises
#
# Short, self-contained exercises to practise the **Python basics** from
# [`../../course/python_fundamentals_course.ipynb`](../../course/python_fundamentals_course.ipynb):
# variables & types, strings/f-strings, lists, dictionaries, tuples, booleans, conditions,
# loops and functions.
#
# **How to use**: complete the cells marked `# Your code here` and run them.
# No dataset and no external library are required — just plain Python.
#
# > ⚠️ Try each exercise **on your own** before opening `solution_fundamentals.ipynb`.

# %% [markdown]
# ---
# ## Exercise 1 — Variables & types
#
# 1. Create three variables: `iban` = the text `"FR7630004000031234567890143"`,
#    `amount` = the number `12500.5`, and `is_cash` = `True`.
# 2. Print the **type** of each variable.
# 3. Print the sentence `"Amount: 12500 EUR"` by **converting** `amount` to a whole number
#    and building the text (use `str(...)` or an f-string).

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 2 — Strings & f-strings
#
# You receive a messy operation label: `label = "  virement SEPA  "`.
#
# 1. Clean it: remove the surrounding spaces and put it in **UPPERCASE**.
# 2. Using an **f-string**, print `Operation: VIREMENT SEPA | 9 characters`
#    (the number is the length of the cleaned label).
# 3. Replace `"VIREMENT"` with `"TRANSFER"` in the cleaned label and print the result.

# %%
label = "  virement SEPA  "
# Your code here

# %% [markdown]
# ---
# ## Exercise 3 — Lists
#
# Given `countries = ['France', 'Panama', 'Cyprus', 'Germany', 'Malta', 'Singapore']`:
#
# 1. Print the **first** and the **last** country.
# 2. Add `'Belgium'` at the end, then print how many countries the list now has.
# 3. Using a **list comprehension**, build `long_names`: the countries whose name has
#    **more than 6 characters**.
# 4. Print a **sorted** copy of the list (without modifying the original).

# %%
countries = ['France', 'Panama', 'Cyprus', 'Germany', 'Malta', 'Singapore']
# Your code here

# %% [markdown]
# ---
# ## Exercise 4 — Dictionaries
#
# You have exchange rates to EUR: `rates = {"EUR": 1.0, "USD": 0.92, "GBP": 1.17}`.
#
# 1. Print the rate for `"USD"`.
# 2. Add a new pair: `"CHF"` → `1.05`.
# 3. Use `.get(...)` to look up `"JPY"` **without causing an error** — return `"unknown"` if absent.
# 4. Print the list of all currencies (the dictionary **keys**).

# %%
rates = {"EUR": 1.0, "USD": 0.92, "GBP": 1.17}
# Your code here

# %% [markdown]
# ---
# ## Exercise 5 — Tuples
#
# A DataFrame shape is given as a tuple: `shape = (506, 10)`.
#
# 1. **Unpack** it into two variables `rows` and `columns` in a single line.
# 2. Print `"506 rows, 10 columns"` using an f-string.

# %%
shape = (506, 10)
# Your code here

# %% [markdown]
# ---
# ## Exercise 6 — Booleans & conditions
#
# For a given `amount`, write an `if / elif / else` that assigns a `category`:
# - `"To declare"` if `amount` is **10000 or more**
# - `"Just below threshold"` if `amount` is **between 9000 and 9999** (inclusive)
# - `"Standard"` otherwise
#
# Test it by printing the category for `amount = 9950`.

# %%
amount = 9950
# Your code here

# %% [markdown]
# ---
# ## Exercise 7 — Loops
#
# Given `amounts = [1200, 9950, 450, 9800, 15000, 300]`:
#
# 1. With a `for` loop, compute the **total** of all amounts.
# 2. With a loop (or a comprehension + `sum`), **count** how many amounts are **strictly above 9000**.
# 3. Print both results.

# %%
amounts = [1200, 9950, 450, 9800, 15000, 300]
# Your code here

# %% [markdown]
# ---
# ## Exercise 8 — Functions
#
# 1. Write a function `to_eur(amount, rate)` that returns `amount * rate` **rounded to 2 decimals**.
# 2. Write a function `risk_category(amount, threshold=10000)` that returns:
#    - `"High"` if `amount >= threshold`
#    - `"Watch"` if `amount >= 90% of threshold`
#    - `"Normal"` otherwise
# 3. Test: print `to_eur(1000, 0.92)` and `risk_category(9950)`.

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 9 — Synthesis (dictionaries + loop + function)
#
# You are given a small list of transactions, each described by a **dictionary**:
#
# ```python
# transactions = [
#     {"id": 1, "amount": 1200.0, "currency": "USD"},
#     {"id": 2, "amount": 9950.0, "currency": "EUR"},
#     {"id": 3, "amount": 800.0,  "currency": "GBP"},
#     {"id": 4, "amount": 15000.0, "currency": "EUR"},
# ]
# rates = {"EUR": 1.0, "USD": 0.92, "GBP": 1.17}
# ```
#
# 1. Loop over `transactions`. For each one, convert its amount to EUR using `rates`
#    (reuse your `to_eur` function and the matching rate for its currency).
# 2. Print, for each transaction, a line like: `Tx 1: 1104.0 EUR`.
# 3. Compute and print the **total in EUR** of all transactions above **1000 EUR** (after conversion).

# %%
transactions = [
    {"id": 1, "amount": 1200.0, "currency": "USD"},
    {"id": 2, "amount": 9950.0, "currency": "EUR"},
    {"id": 3, "amount": 800.0,  "currency": "GBP"},
    {"id": 4, "amount": 15000.0, "currency": "EUR"},
]
rates = {"EUR": 1.0, "USD": 0.92, "GBP": 1.17}
# Your code here
